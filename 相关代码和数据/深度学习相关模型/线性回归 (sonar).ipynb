# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
INPUT_NODE = 60
OUTPUT_NODE = 2

#梯度下降率
GDDOWN = 0.000001

#训练轮数
TRAINING_TIMES = 200

#每次训练数量
TRAINING_STEPS = 100
# Out:
# WARNING:tensorflow:From E:\Anaconda3\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# 各个变量
x = tf.placeholder("float", shape=[None, INPUT_NODE])
y_ = tf.placeholder("float", shape=[None,OUTPUT_NODE])

W = tf.Variable(tf.zeros([INPUT_NODE, OUTPUT_NODE]))
b = tf.Variable(tf.zeros([OUTPUT_NODE]))

# 变量初始化
init = tf.initialize_all_variables()
sess = tf.InteractiveSession()
sess.run(init)

# 初始化图
y = tf.nn.softmax(tf.matmul(x, W) + b)

# 优化算法
cross_entropy = -tf.reduce_sum(y_ * tf.log(y))
train_step =tf.train.GradientDescentOptimizer(GDDOWN).minimize(cross_entropy)
# Out:
# WARNING:tensorflow:From E:\Anaconda3\lib\site-packages\tensorflow_core\python\util\tf_should_use.py:235: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('sonar/sonar.all-data', header = None)
df=df.replace('R',0)
df=df.replace('M',1)
data=df.values
from sklearn.model_selection import train_test_split
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(data[:,0:60],data[:,60], test_size=test_size, random_state=seed)

y_train = tf.one_hot(y_train,2)
y_test = tf.one_hot(y_test,2)
sess1=tf.Session()
y_train, y_test = sess1.run([y_train,y_test])

# %%
history={'accuracy':[],'f_score':[]}

# %%
from sklearn.metrics import f1_score
for i in range(TRAINING_TIMES):
    # 训练
    batch_xs= X_train[i*TRAINING_STEPS:(i+1)*TRAINING_STEPS,:]
    batch_ys= y_train[i*TRAINING_STEPS:(i+1)*TRAINING_STEPS]
    sess.run(train_step, feed_dict={x: batch_xs, y_: batch_ys})
    # 模型评估
    correct_prediction = tf.equal(tf.argmax(y, 1),tf.argmax(y_, 1))
    accuracy =tf.reduce_mean(tf.cast(correct_prediction, "float"))
    pred = tf.argmax(y_, 1)
    true=tf.argmax(y,1)
    j = i+1
    print("第%d轮训练,训练个数%d个" % (j,j*TRAINING_STEPS))
    #print("正确率预测： " + correct_prediction + "\n")
    test_acc,y_pred,y_true=sess.run([accuracy,pred,true],feed_dict={x: X_test, y_:y_test})
    model_f1_score=f1_score(y_true,y_pred,average='micro')
    print( 'f1_score= "{:.9f}"'.format(model_f1_score))
    print("当前正确率： ")
    print(test_acc)
    history['f_score'].append(model_f1_score)
    history['accuracy'].append(test_acc)
# Out:
# 第1轮训练,训练个数100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第2轮训练,训练个数200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第3轮训练,训练个数300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第4轮训练,训练个数400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第5轮训练,训练个数500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第6轮训练,训练个数600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第7轮训练,训练个数700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第8轮训练,训练个数800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第9轮训练,训练个数900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第10轮训练,训练个数1000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第11轮训练,训练个数1100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第12轮训练,训练个数1200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第13轮训练,训练个数1300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第14轮训练,训练个数1400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第15轮训练,训练个数1500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第16轮训练,训练个数1600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第17轮训练,训练个数1700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第18轮训练,训练个数1800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第19轮训练,训练个数1900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第20轮训练,训练个数2000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第21轮训练,训练个数2100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第22轮训练,训练个数2200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第23轮训练,训练个数2300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第24轮训练,训练个数2400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第25轮训练,训练个数2500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第26轮训练,训练个数2600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第27轮训练,训练个数2700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第28轮训练,训练个数2800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第29轮训练,训练个数2900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第30轮训练,训练个数3000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第31轮训练,训练个数3100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第32轮训练,训练个数3200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第33轮训练,训练个数3300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第34轮训练,训练个数3400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第35轮训练,训练个数3500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第36轮训练,训练个数3600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第37轮训练,训练个数3700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第38轮训练,训练个数3800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第39轮训练,训练个数3900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第40轮训练,训练个数4000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第41轮训练,训练个数4100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第42轮训练,训练个数4200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第43轮训练,训练个数4300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第44轮训练,训练个数4400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第45轮训练,训练个数4500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第46轮训练,训练个数4600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第47轮训练,训练个数4700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第48轮训练,训练个数4800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第49轮训练,训练个数4900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第50轮训练,训练个数5000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第51轮训练,训练个数5100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第52轮训练,训练个数5200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第53轮训练,训练个数5300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第54轮训练,训练个数5400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第55轮训练,训练个数5500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第56轮训练,训练个数5600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第57轮训练,训练个数5700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第58轮训练,训练个数5800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第59轮训练,训练个数5900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第60轮训练,训练个数6000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第61轮训练,训练个数6100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第62轮训练,训练个数6200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第63轮训练,训练个数6300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第64轮训练,训练个数6400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第65轮训练,训练个数6500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第66轮训练,训练个数6600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第67轮训练,训练个数6700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第68轮训练,训练个数6800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第69轮训练,训练个数6900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第70轮训练,训练个数7000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第71轮训练,训练个数7100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第72轮训练,训练个数7200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第73轮训练,训练个数7300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第74轮训练,训练个数7400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第75轮训练,训练个数7500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第76轮训练,训练个数7600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第77轮训练,训练个数7700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第78轮训练,训练个数7800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第79轮训练,训练个数7900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第80轮训练,训练个数8000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第81轮训练,训练个数8100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第82轮训练,训练个数8200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第83轮训练,训练个数8300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第84轮训练,训练个数8400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第85轮训练,训练个数8500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第86轮训练,训练个数8600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第87轮训练,训练个数8700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第88轮训练,训练个数8800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第89轮训练,训练个数8900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第90轮训练,训练个数9000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第91轮训练,训练个数9100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第92轮训练,训练个数9200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第93轮训练,训练个数9300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第94轮训练,训练个数9400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第95轮训练,训练个数9500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第96轮训练,训练个数9600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第97轮训练,训练个数9700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第98轮训练,训练个数9800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第99轮训练,训练个数9900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第100轮训练,训练个数10000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第101轮训练,训练个数10100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第102轮训练,训练个数10200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第103轮训练,训练个数10300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第104轮训练,训练个数10400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第105轮训练,训练个数10500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第106轮训练,训练个数10600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第107轮训练,训练个数10700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第108轮训练,训练个数10800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第109轮训练,训练个数10900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第110轮训练,训练个数11000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第111轮训练,训练个数11100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第112轮训练,训练个数11200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第113轮训练,训练个数11300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第114轮训练,训练个数11400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第115轮训练,训练个数11500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第116轮训练,训练个数11600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第117轮训练,训练个数11700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第118轮训练,训练个数11800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第119轮训练,训练个数11900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第120轮训练,训练个数12000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第121轮训练,训练个数12100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第122轮训练,训练个数12200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第123轮训练,训练个数12300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第124轮训练,训练个数12400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第125轮训练,训练个数12500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第126轮训练,训练个数12600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第127轮训练,训练个数12700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第128轮训练,训练个数12800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第129轮训练,训练个数12900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第130轮训练,训练个数13000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第131轮训练,训练个数13100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第132轮训练,训练个数13200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第133轮训练,训练个数13300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第134轮训练,训练个数13400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第135轮训练,训练个数13500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第136轮训练,训练个数13600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第137轮训练,训练个数13700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第138轮训练,训练个数13800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第139轮训练,训练个数13900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第140轮训练,训练个数14000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第141轮训练,训练个数14100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第142轮训练,训练个数14200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第143轮训练,训练个数14300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第144轮训练,训练个数14400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第145轮训练,训练个数14500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第146轮训练,训练个数14600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第147轮训练,训练个数14700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第148轮训练,训练个数14800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第149轮训练,训练个数14900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第150轮训练,训练个数15000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第151轮训练,训练个数15100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第152轮训练,训练个数15200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第153轮训练,训练个数15300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第154轮训练,训练个数15400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第155轮训练,训练个数15500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第156轮训练,训练个数15600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第157轮训练,训练个数15700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第158轮训练,训练个数15800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第159轮训练,训练个数15900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第160轮训练,训练个数16000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第161轮训练,训练个数16100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第162轮训练,训练个数16200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第163轮训练,训练个数16300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第164轮训练,训练个数16400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第165轮训练,训练个数16500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第166轮训练,训练个数16600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第167轮训练,训练个数16700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第168轮训练,训练个数16800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第169轮训练,训练个数16900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第170轮训练,训练个数17000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第171轮训练,训练个数17100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第172轮训练,训练个数17200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第173轮训练,训练个数17300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第174轮训练,训练个数17400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第175轮训练,训练个数17500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第176轮训练,训练个数17600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第177轮训练,训练个数17700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第178轮训练,训练个数17800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第179轮训练,训练个数17900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第180轮训练,训练个数18000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第181轮训练,训练个数18100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第182轮训练,训练个数18200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第183轮训练,训练个数18300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第184轮训练,训练个数18400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第185轮训练,训练个数18500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第186轮训练,训练个数18600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第187轮训练,训练个数18700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第188轮训练,训练个数18800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第189轮训练,训练个数18900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第190轮训练,训练个数19000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第191轮训练,训练个数19100个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第192轮训练,训练个数19200个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第193轮训练,训练个数19300个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第194轮训练,训练个数19400个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第195轮训练,训练个数19500个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第196轮训练,训练个数19600个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第197轮训练,训练个数19700个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第198轮训练,训练个数19800个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第199轮训练,训练个数19900个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246
# 第200轮训练,训练个数20000个
# f1_score= "0.550724638"
# 当前正确率：
# 0.5507246

# %%
# 构造绘图函数
from matplotlib import pyplot as plt
def drow(history):
    plt.figure()
    epochs = range(1, len(history['accuracy']) + 1)
    plt.plot(epochs, history['accuracy'], 'rx', label='accuracy')
    plt.plot(epochs, history['f_score'], 'b', label='f1_score')
    plt.title('acc and f1_score')
    plt.xlabel('Epochs')
    plt.ylabel('acc/f1_score')
    plt.legend()
    plt.show()

# %%
drow(history)
